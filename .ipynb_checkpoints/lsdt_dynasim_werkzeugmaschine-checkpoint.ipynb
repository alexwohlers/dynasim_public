# %%
from lsdt_dynasim import*

from matplotlib import pyplot as plt
import matplotlib
import numpy as np
import math
from scipy.interpolate import interp1d
  
#########################################################################
##### Beschreibung Programm #############################################
#########################################################################

""" 
Das Programm dient der Berechnung des Systemverhaltens von Schwingungsfähigen Systemen

Bemerkungen:
- Die numerische Berechnung erfolgt mittels Runge Kutta Verfahren (RK4)
- Die Genauigkeit der Ergebnisse hängen von der Zeitschrittweite und der Simulationsdauer ab
- Eine zu kein gewählte Schrittweite führt in der Regel zu einer Energiezufuhr ins System
- Je höher die Steifigkeit des Systems, desto kleiner muss die Simulationsschrittweite gewählt werden
"""
#########################################################################
##### Allgemeine Einstellungen ##########################################
#########################################################################

Bilder_speichern                     = True
CSV_speichern                        = True
CSV_speichern_Blender                = False

#########################################################################
##### Messung einlesen (optional) #######################################
#########################################################################

#########################################################################
##### Simulationsparameter ##############################################
#########################################################################

Input_t_start                        = 0             # Simulationszeit Star
Input_t_ende                         = 20            # Simulationszeit Ende
Input_delta_t                        = 0.00001       # Zeitschrittweite

# Initial and end values
Input_gx                             = 0             # Gravitationsbeschleunigung x-Richtung, Standard: 0
Input_gy                             = 0             # Gravitationsbeschleunigung y-Richtung, Standard: 0
Input_gz                             = -9.81         # Gravitationsbeschleunigung z-Richtung, Standard: -9.81

# Initial and end values
Input_E1_Masse_Feder_E                     = 2.1e11        # E-Modul
Input_E1_Masse_Feder_I                     = 2e-10         # Flächenträgheitsmoment
Input_E1_Masse_Feder_L                     = 0.5           # Länge der Feder
Input_E1_Masse_Feder_Fv                    = 0             # Federvorspannkraft (zur Kompensation von Gewichtskräften, Positiv: Kraft zieht Feder zusammen, Negativ: Kraft drückt Feder auseinander)
Input_E2_Masse_Masse_m                     = 50            # Masse

Input_E6_Masse_Daempfer_d                  = 50            # Dämpfungskonstante

Input_E7_Masse_Kraftamplitude_F            = 10            # Kraftamplitude
Input_E7_Masse_Anregungsfrequenz_omega     = 10            # Anregungsfrequenz

#########################################################################
##### Anfangsrandbedingungen der Elemente ###############################
#########################################################################

K2_Masse.z   = 0.0

#########################################################################
##### Erstellung aller Elemente #########################################
#########################################################################
"""
Modell:
    E1_Masse:   Feder
    E2_Masse:   Feder
    E3_Masse:   Feder
    E4_Masse:   Feder
    E5_Masse:   Masse
    E6_Masse:   Dämpfer
    E7_Masse:   Kraftanregung
"""

E1_Masse                               = class_Blattfeder_beidseitig_fest_eingespannt_x_Masse(Input_E1_Masse_Feder_L, Input_E1_Masse_Feder_E, Input_E1_Masse_Feder_I, Input_E1_Masse_Feder_Fv, [K1_Masse, K5_Masse])
E2_Masse                               = class_Blattfeder_beidseitig_fest_eingespannt_x_Masse(Input_E1_Masse_Feder_L, Input_E1_Masse_Feder_E, Input_E1_Masse_Feder_I, Input_E1_Masse_Feder_Fv, [K2_Masse, K5_Masse])
E3_Masse                               = class_Blattfeder_beidseitig_fest_eingespannt_x_Masse(Input_E1_Masse_Feder_L, Input_E1_Masse_Feder_E, Input_E1_Masse_Feder_I, Input_E1_Masse_Feder_Fv, [K3_Masse, K5_Masse])
E4_Masse                               = class_Blattfeder_beidseitig_fest_eingespannt_x_Masse(Input_E1_Masse_Feder_L, Input_E1_Masse_Feder_E, Input_E1_Masse_Feder_I, Input_E1_Masse_Feder_Fv, [K4_Masse, K5_Masse])
E5_Masse                               = class_DGL_Masse_trans_x_Masse(Input_E2_Masse_Masse_m, Input_gx, [K5_Masse])
E6_Masse                               = class_Daempfer_x_Masse(Input_E6_Masse_Daempfer_d, [K6_Masse, K5_Masse])
E7_Masse                               = class_Kraftanregung_x_Masse(Input_E7_Masse_Kraftamplitude_F, Input_E7_Masse_Anregungsfrequenz_omega, [K5_Masse])

#########################################################################
##### Start der Simulation ##############################################
#########################################################################

t = Input_t_start
while (t < Input_t_ende):
    # Erst einmal alle Knotenkräfte zu Null setzen, da diese an den Knoten aufsummiert werden
    Reset_Knotenkraefte_Masse()            
                                
    #Berechnung der Kräfte an den Federn und Dämpfern
    #    für alle Elemente
    E1_Masse.Berechnung_Kraefte()
    E2_Masse.Berechnung_Kraefte()    
    E3_Masse.Berechnung_Kraefte()    
    E4_Masse.Berechnung_Kraefte()    
    E5_Masse.Berechnung_Kraefte()    
    E6_Masse.Berechnung_Kraefte()    
    
    #Kraftanregungen
    E7_Masse.Berechnung_Anregung(t)
    
    #Berechung der massebehafteten Elemente  
    #    nur für Elemente mit Masse
    E5_Masse.Loesung_Differentialgleichung_Zeitschritt(Input_delta_t)          
    
    # Berechnung Energien    
    #    für alle Elemente
    E1_Masse.Berechnung_Energien(Input_delta_t)    
    E2_Masse.Berechnung_Energien(Input_delta_t)        
    E3_Masse.Berechnung_Energien(Input_delta_t)        
    E4_Masse.Berechnung_Energien(Input_delta_t)        
    E5_Masse.Berechnung_Energien(Input_delta_t)        
    E6_Masse.Berechnung_Energien(Input_delta_t)        
    
    # Datenlogger Knoten
    Datenlogger_Knoten_schreiben_Masse(t)
    
    #Datenlogger Elemente
    #    für alle Elemente
    datenlogger_E1_Masse.Werte_anhaengen(E1_Masse)
    datenlogger_E2_Masse.Werte_anhaengen(E2_Masse)    
    datenlogger_E3_Masse.Werte_anhaengen(E3_Masse)    
    datenlogger_E4_Masse.Werte_anhaengen(E4_Masse)    
    datenlogger_E5_Masse.Werte_anhaengen(E5_Masse)    
    datenlogger_E6_Masse.Werte_anhaengen(E6_Masse)    
                          
    t = t + Input_delta_t

if (CSV_speichern == True):
    csv_schreiben_Masse('../output_csv/lsdt_dynasim_werkzeugmaschine.csv',datenlogger_K2_Masse)
    
if (CSV_speichern_Blender == True):
    csv_schreiben_Masse('../output_csv_blender/lsdt_dynasim_werkzeugmaschine_K2.csv',datenlogger_K2_Masse)

# %%
fig = plt.figure()
fig.patch.set_facecolor('white')
plt.title('Feder-Masse: Knotenverlagerungen x-Richtung')
plt.plot(datenlogger_t_Masse,datenlogger_K5_Masse.x,label='K5_Masse [m]')
#plt.xlim(0,20)
plt.xlabel('Zeit [s]')
plt.grid(True)
plt.legend()
if (Bilder_speichern == True):
    plt.savefig('../output_bilder/lsdt_dynasim_werkzeugmaschine1.png')

# %%
fig = plt.figure()
fig.patch.set_facecolor('white')
plt.title('Feder-Masse: Knotenkräfte x-Richtung')
plt.plot(datenlogger_t_Masse,datenlogger_K5_Masse.F_x,label='Feder [N]')
#plt.xlim(0,20)
plt.xlabel('Zeit [s]')
plt.grid(True)
plt.legend()
if (Bilder_speichern == True):
    plt.savefig('../output_bilder/lsdt_dynasim_werkzeugmaschine2.png')

# %%
fig = plt.figure()
fig.patch.set_facecolor('white')
plt.title('Feder-Masse: Phasendiagramm')
plt.plot(datenlogger_K5_Masse.x,datenlogger_K5_Masse.x_p,label='Masse')
#plt.xlim(0,20)
plt.xlabel('Weg [m]')
plt.ylabel('Geschwindigkeit [m/s]')
plt.grid(True)
#plt.legend()
if (Bilder_speichern == True):
    plt.savefig('../output_bilder/lsdt_dynasim_werkzeugmaschine3.png')

# %%
fig = plt.figure()
fig.patch.set_facecolor('white')
plt.title('Feder-Masse: Energiebilanz')
E_ges = []
for point in range(len(datenlogger_E2_Masse.E_pot)):
    E_ges.append(datenlogger_E1_Masse.E_pot[point] + datenlogger_E2_Masse.E_pot[point] + datenlogger_E3_Masse.E_pot[point] + datenlogger_E4_Masse.E_pot[point] + datenlogger_E5_Masse.E_kin[point])
plt.plot(datenlogger_t_Masse,datenlogger_E1_Masse.E_pot,label='E_pot Feder')
plt.plot(datenlogger_t_Masse,datenlogger_E2_Masse.E_pot,label='E_pot Feder')
plt.plot(datenlogger_t_Masse,datenlogger_E3_Masse.E_pot,label='E_pot Feder')
plt.plot(datenlogger_t_Masse,datenlogger_E4_Masse.E_pot,label='E_pot Feder')
plt.plot(datenlogger_t_Masse,datenlogger_E5_Masse.E_kin,label='E_kin Masse')
plt.plot(datenlogger_t_Masse,E_ges,label='E_ges')
#plt.xlim(0,20)
plt.xlabel('Zeit [s]')
plt.ylabel('Energie [J]')
plt.grid(True)
plt.legend()
if (Bilder_speichern == True):
    plt.savefig('../output_bilder/lsdt_dynasim_werkzeugmaschine4.png')
